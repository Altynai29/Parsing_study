# %% [markdown]
# <a href="https://colab.research.google.com/github/Altynai29/Parsing_study/blob/main/%22films_dataset_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3
pd.set_option("display.max_columns", 50)

# %%
# !wget 'https://www.dropbox.com/scl/fi/0eqkblwjqmfljk9tcr2wm/films_sql.db?rlkey=ukds5y460mvltkuoir2z7hoky&dl=0' -O films_sql.db
# Out:
# films_sql.db        100%[===================>] 853.84M  45.8MB/s    in 28s
#
# 2024-03-11 14:40:50 (30.1 MB/s) - ‘films_sql.db’ saved [895320064/895320064]

# %%
sql_file = 'films_sql.db'

# %%
conn = sqlite3.connect(sql_file)

# %%
query = "SELECT * FROM lincs"
lincs = pd.read_sql_query(query, conn)

# %%
query = "SELECT * FROM credits"
credits = pd.read_sql_query(query, conn)

# %%
query = "SELECT * FROM keywords"
keywords = pd.read_sql_query(query, conn)

# %%
query = "SELECT * FROM movies_metadata"
movies_metadata = pd.read_sql_query(query, conn)

# %%
query = "SELECT * FROM ratings"
ratings = pd.read_sql_query(query, conn)

# %%
conn.close()

# %% [markdown]
# # About Dataset
# ## Context
# These files contain metadata for all 45,000 movies listed in the Full MovieLens Dataset. The dataset consists of movies released on or before July 2017. Data points include cast, crew, plot keywords, budget, revenue, posters, release dates, languages, production companies, countries, TMDB vote counts and vote averages.
#
# This dataset also has files containing 26 million ratings from 270,000 users for all 45,000 movies. Ratings are on a scale of 1-5 and have been obtained from the official GroupLens website.
#
# ## Content
# This dataset consists of the following files:
#
# ### movies_metadata.csv:
#
# The main Movies Metadata file. Contains information on 45,000 movies featured in the Full MovieLens dataset. Features include posters, backdrops, budget, revenue, release dates, languages, production countries and companies.
#
# ### keywords.csv:
#
# Contains the movie plot keywords for our MovieLens movies. Available in the form of a stringified JSON Object.
#
# ### credits.csv:
#
#
# Consists of Cast and Crew Information for all our movies. Available in the form of a stringified JSON Object.
#
# ### links.csv:
#
# The file that contains the TMDB and IMDB IDs of all the movies featured in the Full MovieLens dataset.
#
# ###links_small.csv:
#
# Contains the TMDB and IMDB IDs of a small subset of 9,000 movies of the Full Dataset.
#
# ratings_small.csv:
#
# The subset of 100,000 ratings from 700 users on 9,000 movies.
#
# The Full MovieLens Dataset consisting of 26 million ratings and 750,000 tag applications from 270,000 users on all the 45,000 movies in this dataset can be accessed here
#
# Acknowledgements
# This dataset is an ensemble of data collected from TMDB and GroupLens. The Movie Details, Credits and Keywords have been collected from the TMDB Open API. This product uses the TMDb API but is not endorsed or certified by TMDb. Their API also provides access to data on many additional movies, actors and actresses, crew members, and TV shows. You can try it for yourself here.
#
# The Movie Links and Ratings have been obtained from the Official GroupLens website. The files are a part of the dataset available here
#
# Inspiration
# This dataset was assembled as part of my second Capstone Project for Springboard's Data Science Career Track. I wanted to perform an extensive EDA on Movie Data to narrate the history and the story of Cinema and use this metadata in combination with MovieLens ratings to build various types of Recommender Systems.
#
# Both my notebooks are available as kernels with this dataset: The Story of Film and Movie Recommender Systems
#
# Some of the things you can do with this dataset: Predicting movie revenue and/or movie success based on a certain metric. What movies tend to get higher vote counts and vote averages on TMDB? Building Content Based and Collaborative Filtering Based Recommendation Engines.

# %%
movies_metadata.rename({'id': 'tmdbId'}, axis=1, inplace=True)
movies_metadata.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                               None  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage tmdbId    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                  None   8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                    tagline      title  video  \
# 0  Released                                       None  Toy Story    0.0
# 1  Released  Roll the dice and unleash the excitement!    Jumanji    0.0
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0

# %%
movies_metadata.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
movies_metadata.shape
# Out:
# (45466, 24)

# %%
keywords.rename({'id': 'tmdbId'}, axis=1, inplace=True)
keywords.head()
# Out:
#    tmdbId                                           keywords
# 0     862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1    8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2   15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3   31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4   11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
keywords.keywords[0]
# Out:
# "[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]"

# %%
lincs.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
credits.rename({'id': 'tmdbId'}, axis=1, inplace=True)
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  tmdbId
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862

# %%
credits.cast[0]

# %%
import ast
def str_to_list(x:str)->list:
  return ast.literal_eval(x)

# %%
str_to_list(credits.cast[0])

# %%
pd.DataFrame(str_to_list(credits.cast[0]))

# %%
credits.tmdbId.info()

# %%
credits.tmdbId = credits.tmdbId.astype(str)

# %%
movies_metadata.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                               None  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage tmdbId    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                  None   8844  tt0113497                en
#
#   original_title                                           overview  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                    tagline      title  video  \
# 0  Released                                       None  Toy Story    0.0
# 1  Released  Roll the dice and unleash the excitement!    Jumanji    0.0
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0

# %%
movies_metadata.shape
# Out:
# (45466, 24)

# %%
ratings = pd.merge(ratings, lincs, on='movieId', how='left')

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp   imdbId   tmdbId
# 0              1      110     1.0  1425941529   112573    197.0
# 1              1      147     4.5  1425942435   112461  10474.0
# 2              1      858     5.0  1425941523    68646    238.0
# 3              1     1221     5.0  1425941546    71562    240.0
# 4              1     1246     5.0  1425941556    97165    207.0
# ...          ...      ...     ...         ...      ...      ...
# 26024284  270896    58559     5.0  1257031564   468569    155.0
# 26024285  270896    60069     5.0  1257032032   910970  10681.0
# 26024286  270896    63082     4.5  1257031764  1010048  12405.0
# 26024287  270896    64957     4.5  1257033990   421715   4922.0
# 26024288  270896    71878     2.0  1257031858   814335  19904.0
#
# [26024289 rows x 6 columns]

# %%
mean_rat = ratings.groupby(by='tmdbId', as_index=False).agg(mean_rating = ('rating', 'mean'))

# %%
mean_rat

# %%
mean_rat.tmdbId=mean_rat.tmdbId.astype(int).astype(str)

# %%
movies_metadata = pd.merge(movies_metadata, mean_rat, how='left')
movies_metadata

# %%
movies_metadata
# Out:
#                                                   genres  tmdbId  mean_rating
# 40719                      [{'id': 18, 'name': 'Drama'}]  295886          5.0
# 41012                  [{'id': 16, 'name': 'Animation'}]   69484          5.0
# 42978                      [{'id': 18, 'name': 'Drama'}]  255552          5.0
# 41846                                                 []  318794          5.0
# 41849                                                 []  350594          5.0
# ...                                                  ...     ...          ...
# 43223  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...   37037          NaN
# 44923  [{'id': 10751, 'name': 'Family'}, {'id': 878, ...   84626          NaN
# 45086                                                 []  425071          NaN
# 45207                      [{'id': 18, 'name': 'Drama'}]  414453          NaN
# 45465                                                 []  461257          NaN
#
# [45466 rows x 3 columns]

# %%
movies_metadata = movies_metadata[['genres', 'tmdbId', 'mean_rating']]

# %%
movies_metadata.sort_values('mean_rating', ascending=False, inplace=True)
movies_metadata_10 = movies_metadata.head(10)
# Out:
# <ipython-input-57-3d4c0b990d38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_metadata.sort_values('mean_rating', ascending=False, inplace=True)

# %%
movies_metadata_10 = movies_metadata_10.merge(credits[['cast', 'tmdbId']], on='tmdbId', how='left')

# %%
movies_metadata_10

# %%
def get_actor(row: str) -> str:
   try:
     return str_to_list(row)[0]['name']
   except Exception:
    return np.nan

# %%
movies_metadata_10.cast.map(get_actor)
# Out:
# 0          Keke Palmer
# 1                  NaN
# 2    Sebastian Zimmler
# 3                  NaN
# 4                  NaN
# 5        Graham Greene
# 6      Nicolas Yumatov
# 7     Julie Zangenberg
# 8                  NaN
# 9        Nikki DeLoach
# Name: cast, dtype: object

# %%
movies_metadata = movies_metadata.merge(credits[['cast', 'tmdbId']], on='tmdbId', how='left')

# %%
movies_metadata['actor'] = movies_metadata.cast.map(get_actor)

# %%
al_pacino = movies_metadata.loc[movies_metadata.actor == 'Al Pacino'].reset_index()

# %%
al_pacino.genres[0]
# Out:
# "[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]"

# %%
str_to_list(al_pacino.genres[0])
# Out:
# [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]

# %%
def get_generes(row: str) -> str:
  generes = ''
  for i in str_to_list(row):
    generes = generes + i['name'] + ', '
  return generes.strip(', ')

# %%
get_generes(al_pacino.genres[3])

# %%
al_pacino.genres = al_pacino.genres.map(get_generes)

# %%
#pd.concat([al_pacino, al_pacino.genres.str.get_dummies(sep=', ')], axis=1)
al_pacino.genres.str.get_dummies(sep=', ').sum(axis=0)
# Out:
# Action              5
# Adventure           1
# Comedy              5
# Crime              13
# Documentary         1
# Drama              29
# Fantasy             1
# History             2
# Horror              1
# Music               1
# Mystery             6
# Romance             4
# Science Fiction     1
# Thriller           14
# War                 1
# dtype: int64
